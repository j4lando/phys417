# %%
import torch

class myModel(torch.nn.Module):
    
    def __init__(self, input_dim, output_dim):
        
        super(myModel, self).__init__()
        
        self.layer1 = torch.nn.Linear(10, 32)
        self.layer2 = torch.nn.Linear(32, 16)
        self.layer2 = torch.nn.Linear(16, 5)
        
    def forward(self, x):
        
        out = self.nn.Sigmoid(self.layer1(x))
        out = self.nn.Sigmoid(self.layer2(out))
        out = self.nn.Dropout(p=.3)(out)
        out = self.nn.SoftMax(self.layer3(out))
        
        return out
